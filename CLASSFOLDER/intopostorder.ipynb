# %%
#Inorder Expression to Postorder Expression
inorder = "E,D,F,B,A,H,C,G"
stack = []
output = []

# %%
#Enter the Inorder to post order Expression
#Code to Write a function to convert inorder to postorder Expression

def inorder_to_postorder():
    expression = input("Enter the Inorder Expression: ")    
    stack = []
    output = []
    # precedence of operators
    Sequence = {
